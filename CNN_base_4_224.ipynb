# %% [markdown]
# # CNN as baseline

# %%
import os,gc,time
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.models import Model, load_model, Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Conv2D, BatchNormalization, Dropout, MaxPooling2D, Flatten
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.backend import clear_session

RANDOM_SEED = 2023 # random seed for k-fold cross-validation
BATCH_SIZE = 16  
EPOCH_NUM = 100
FOLD_NUM = 5
num_channels = 3 # number of channels = 3: RGB
image_size = (224, 224) # set image size

# early stop metrics monitoring validation loss, in order to compare models, set all epoch=50 fixed, not used now.
#early_stopping_loss = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#early_stopping_accuracy = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
#CALLBACKS = [early_stopping_loss, early_stopping_accuracy]

# set CUDA environment variables
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # use GPU0
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE" # reduce potential conflict of packages
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = "true" # GPU memory management

# set data dir
data_dir = "./data/merged_aug_data_224"
#train_dir = "./data/aug_data_224/Train"
#test_dir = "./data/aug_data_224/Test"

# set folder address, avoid duplicated directory name
model_weights_dir = './models/CNN_base'
model_id = 0
while os.path.exists(model_weights_dir):
    model_id += 1
    model_weights_dir = f'./models/CNN_base{model_id}/'
if not os.path.exists(model_weights_dir):
    os.makedirs(model_weights_dir)

# save all configurations in a txt file
with open(os.path.join(model_weights_dir, 'info.txt'), 'w') as file:
    variables = {
        'RANDOM_SEED': RANDOM_SEED,
        'BATCH_SIZE': BATCH_SIZE,
        'EPOCH_NUM': EPOCH_NUM,
        'FOLD_NUM': FOLD_NUM,
        'num_channels': num_channels,
        'image_size': image_size,
        #'monitor of early_stopping_loss':early_stopping_loss.monitor,
        #'patience of early_stopping_loss':early_stopping_loss.patience,
        #'restore_best_weights of early_stopping_loss':early_stopping_loss.restore_best_weights,
        #'monitor of early_stopping_accuracy': early_stopping_loss.monitor,
        #'patience of early_stopping_accuracy': early_stopping_loss.patience,
        #'restore_best_weights of early_stopping_accuracy': early_stopping_loss.restore_best_weights,
        'CUDA_VISIBLE_DEVICES': os.environ["CUDA_VISIBLE_DEVICES"],
        'KMP_DUPLICATE_LIB_OK': os.environ["KMP_DUPLICATE_LIB_OK"],
        'TF_FORCE_GPU_ALLOW_GROWTH': os.environ['TF_FORCE_GPU_ALLOW_GROWTH'],
        'data_dir:' : data_dir
        #'train_dir': train_dir,
        #'test_dir': test_dir
    }
    for variable, value in variables.items():
        file.write(f'{variable} = {value}\n')
print('Model weights have been saved at：', model_weights_dir)
# Out:
# C:\DevTools\Anaconda3\envs\tf\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# Model weights have been saved at： ./models/CNN_base4/

# %% [markdown]
# # Design the weak model 2

# %%
def create_model():
    model = Sequential()
    model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(image_size[0], image_size[1], num_channels)))
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(4, 4)))
    model.add(Conv2D(64, kernel_size=(5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(4, 4)))
    
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.20))
    
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %% [markdown]
# # Loading datasets

# %%
#Load training set and test set, and their labels
def load_images_and_labels(directory):
    images = []
    labels = []
    class_names = os.listdir(directory)
    for class_name in class_names:
        class_dir = os.path.join(directory, class_name)
        print(f'loading images from {class_dir}')
        for filename in tqdm(os.listdir(class_dir)):
            image_path = os.path.join(class_dir, filename)
            try:
                image = cv2.imread(image_path)
                #image = tf.cast(image, tf.float16) / 255.0 # normalize, out of memeory
                #image = cv2.resize(image, image_size)
                images.append(image)
                labels.append(class_names.index(class_name))
            except Exception as e:
                print(f"Error loading image: {image_path}")
                print(f"Error message: {e}")
    return np.array(images), np.array(labels)

# %%
# Get training set and test set, and their label
images, labels = load_images_and_labels(data_dir)
# Out:
# loading images from ./data/merged_aug_data_224\Mild
# 100%|██████████████████████████████████████████████████████████████████████████| 11200/11200 [00:07<00:00, 1445.09it/s]
# loading images from ./data/merged_aug_data_224\Moderate
# 100%|██████████████████████████████████████████████████████████████████████████| 16372/16372 [00:11<00:00, 1409.27it/s]
# loading images from ./data/merged_aug_data_224\Non
# 100%|██████████████████████████████████████████████████████████████████████████| 12800/12800 [00:08<00:00, 1442.57it/s]

# %% [markdown]
# # Training the model with 5-fold cross-validation

# %% [markdown]
# Use StratifiedKFold(n_splits=FOLD_NUM, shuffle=True, random_state=RANDOM_SEED) to split training set into 5 folds.

# %%
def get_checkpoint_for_fold(model_id):
    '''
    return checkpoint for each fold of cross-validation
    '''
    checkpoint = ModelCheckpoint(model_weights_dir + f'/best_model_{model_id}.h5', 
                                 monitor='val_loss',
                                 save_best_only=True,
                                 save_weights_only=False,
                                 mode='min',
                                 verbose=2)
    return checkpoint

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=20,          
    restore_best_weights=True  
)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, confusion_matrix, classification_report
def test_model(model, test_images, test_labels):
    # use data in test set to make predictions
    test_probabilities = model.predict(test_images)
    test_predictions = np.argmax(test_probabilities, axis=1)

    # calculate metrics
    accuracy = accuracy_score(test_labels, test_predictions)
    f1 = f1_score(test_labels, test_predictions, average='weighted')
    precision = precision_score(test_labels, test_predictions, average='weighted')
    recall = recall_score(test_labels, test_predictions, average='weighted')
    confusion_mat = confusion_matrix(test_labels, test_predictions)
    weighted_auc_ovr = roc_auc_score(test_labels, test_probabilities, average='weighted',multi_class='ovr')
    #print(weighted_auc_ovr)
    weighted_auc_ovo = roc_auc_score(test_labels, test_probabilities, average='weighted',multi_class='ovo')
    #print(weighted_auc_ovo)
    print(f'Test set performance:')
    print("Weighted AUC(OvR):", weighted_auc_ovr)
    print("Weighted AUC(OvO):", weighted_auc_ovo)
    print(f'Weighted F1 score = {f1}')
    print(f'Weighted Precision = {precision}, Weighted Recall = {recall}, Accuracy = {accuracy}')
    print('Confusion matrix:\n')
    print(confusion_mat)

    # get the result of classification report
    report = classification_report(test_labels, test_predictions)
    print(f'Result of classification report:\n')
    print(report)
    return f1, weighted_auc_ovr, weighted_auc_ovo

# %%
# memory leaking solved by adding gc.collect(), decreasing image size and batch size also helps.
# Following loop works with 32 Gib RAM PC
# set fold with a fixed random seed
kf = StratifiedKFold(n_splits=FOLD_NUM, shuffle=True, random_state=RANDOM_SEED)

#accuracy_list = []
weighted_f1_list = []
auc_ovr_list = []
auc_ovo_list = []
#precision_list = []
#recall_list = []
fold_id = 0

# 5-fold cross-validation
for train_index, test_index in  kf.split(images, labels):
    train_images_fold, test_images_fold = images[train_index], images[test_index]
    train_labels_fold, test_labels_fold = labels[train_index], labels[test_index]
    
    # get model
    model = create_model()

    best_epoch = get_checkpoint_for_fold(fold_id)
    
    # train the model
    print(f'training on fold {fold_id}:')
    history = model.fit(train_images_fold, train_labels_fold, 
                        epochs=EPOCH_NUM, 
                        batch_size=BATCH_SIZE,
                        validation_split=0.2,
                        callbacks=[best_epoch, early_stopping],
                        verbose=1)
    best_model_weight_dir = model_weights_dir + f'/best_model_{fold_id}.h5'

    if os.path.exists(best_model_weight_dir):
        #best_model = create_model(input_shape=(image_size[0], image_size[1], num_channels), num_classes=3)
        best_model = load_model(best_model_weight_dir)
        f1, auc_ovr, auc_ovo = test_model(model, test_images_fold, test_labels_fold)
        
        # store the values of metrics
        weighted_f1_list.append(f1)
        auc_ovr_list.append(auc_ovr)
        auc_ovo_list.append(auc_ovo)

        #move on for next fold
        fold_id += 1

    # get training history
    loss = history.history['loss']
    accuracy = history.history['accuracy']
    val_loss = history.history['val_loss']
    val_accuracy = history.history['val_accuracy']

    # Get Loss-epoch plot
    num_epochs = len(loss)
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.plot(range(1, num_epochs + 1), loss, label='Training Loss', color='blue')
    plt.plot(range(1, num_epochs + 1), val_loss, label='Validation Loss', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy changes with epoch plot
    plt.subplot(1, 2, 2)
    plt.plot(range(1, num_epochs + 1), accuracy, label='Training Accuracy', color='blue')
    plt.plot(range(1, num_epochs + 1), val_accuracy, label='Validation Accuracy', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

    # releases the memory when there are many models in a loop
    try:
        del model, history, train_images_fold, test_images_fold, train_labels_fold, test_labels_fold
    except Exception as e:
        print(f"fail to release memory")
        print(f"Error message: {e}")
    # finnish a full collection
    gc.collect()
    clear_session()
# Out:
# training on fold 0:
# Epoch 1/100
# 1615/1615 [==============================] - 26s 13ms/step - loss: 0.8010 - accuracy: 0.6259 - val_loss: 1.6382 - val_accuracy: 0.2635
#
# Epoch 00001: val_loss improved from inf to 1.63819, saving model to ./models/CNN_base4\best_model_0.h5
# Epoch 2/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.6235 - accuracy: 0.7221 - val_loss: 1.3143 - val_accuracy: 0.3197
#
# Epoch 00002: val_loss improved from 1.63819 to 1.31430, saving model to ./models/CNN_base4\best_model_0.h5
# Epoch 3/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.5226 - accuracy: 0.7710 - val_loss: 1.2517 - val_accuracy: 0.4215
#
# Epoch 00003: val_loss improved from 1.31430 to 1.25165, saving model to ./models/CNN_base4\best_model_0.h5
# Epoch 4/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.4393 - accuracy: 0.8145 - val_loss: 1.2344 - val_accuracy: 0.3757
#
# Epoch 00004: val_loss improved from 1.25165 to 1.23437, saving model to ./models/CNN_base4\best_model_0.h5
# Epoch 5/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3765 - accuracy: 0.8388 - val_loss: 1.5206 - val_accuracy: 0.4087
#
# Epoch 00005: val_loss did not improve from 1.23437
# Epoch 6/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3270 - accuracy: 0.8624 - val_loss: 1.9221 - val_accuracy: 0.3540
#
# Epoch 00006: val_loss did not improve from 1.23437
# Epoch 7/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2878 - accuracy: 0.8814 - val_loss: 1.9444 - val_accuracy: 0.4036
#
# Epoch 00007: val_loss did not improve from 1.23437
# Epoch 8/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2568 - accuracy: 0.8928 - val_loss: 1.5899 - val_accuracy: 0.5251
#
# Epoch 00008: val_loss did not improve from 1.23437
# Epoch 9/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2260 - accuracy: 0.9053 - val_loss: 1.6276 - val_accuracy: 0.5190
#
# Epoch 00009: val_loss did not improve from 1.23437
# Epoch 10/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2083 - accuracy: 0.9137 - val_loss: 1.4918 - val_accuracy: 0.5613
#
# Epoch 00010: val_loss did not improve from 1.23437
# Epoch 11/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1863 - accuracy: 0.9239 - val_loss: 1.9060 - val_accuracy: 0.5184
#
# Epoch 00011: val_loss did not improve from 1.23437
# Epoch 12/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1792 - accuracy: 0.9284 - val_loss: 1.6251 - val_accuracy: 0.6122
#
# Epoch 00012: val_loss did not improve from 1.23437
# Epoch 13/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1690 - accuracy: 0.9304 - val_loss: 1.7708 - val_accuracy: 0.6025
#
# Epoch 00013: val_loss did not improve from 1.23437
# Epoch 14/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1541 - accuracy: 0.9368 - val_loss: 2.4736 - val_accuracy: 0.5342
#
# Epoch 00014: val_loss did not improve from 1.23437
# Epoch 15/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1489 - accuracy: 0.9406 - val_loss: 2.5920 - val_accuracy: 0.5435
#
# Epoch 00015: val_loss did not improve from 1.23437
# Epoch 16/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1355 - accuracy: 0.9460 - val_loss: 2.5731 - val_accuracy: 0.5169
#
# Epoch 00016: val_loss did not improve from 1.23437
# Epoch 17/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1345 - accuracy: 0.9482 - val_loss: 2.6546 - val_accuracy: 0.5426
#
# Epoch 00017: val_loss did not improve from 1.23437
# Epoch 18/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1295 - accuracy: 0.9499 - val_loss: 1.3873 - val_accuracy: 0.7324
#
# Epoch 00018: val_loss did not improve from 1.23437
# Epoch 19/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1250 - accuracy: 0.9525 - val_loss: 2.3918 - val_accuracy: 0.5842
#
# Epoch 00019: val_loss did not improve from 1.23437
# Epoch 20/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1196 - accuracy: 0.9542 - val_loss: 2.9618 - val_accuracy: 0.5559
#
# Epoch 00020: val_loss did not improve from 1.23437
# Epoch 21/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1147 - accuracy: 0.9559 - val_loss: 2.7607 - val_accuracy: 0.5949
#
# Epoch 00021: val_loss did not improve from 1.23437
# Epoch 22/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1111 - accuracy: 0.9557 - val_loss: 2.7933 - val_accuracy: 0.5808
#
# Epoch 00022: val_loss did not improve from 1.23437
# Epoch 23/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1093 - accuracy: 0.9581 - val_loss: 3.2688 - val_accuracy: 0.5311
#
# Epoch 00023: val_loss did not improve from 1.23437
# Epoch 24/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1110 - accuracy: 0.9589 - val_loss: 2.5888 - val_accuracy: 0.6156
#
# Epoch 00024: val_loss did not improve from 1.23437
# Test set performance:
# Weighted AUC(OvR): 0.9195827543274272
# Weighted AUC(OvO): 0.9106440044006127
# Weighted F1 score = 0.721826039399566
# Weighted Precision = 0.7807164834261189, Weighted Recall = 0.7261919504643963, Accuracy = 0.7261919504643963
# Confusion matrix:
#
# [[1894  177  169]
#  [ 414 2846   15]
#  [1263  173 1124]]
# Result of classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.53      0.85      0.65      2240
#            1       0.89      0.87      0.88      3275
#            2       0.86      0.44      0.58      2560
#
#     accuracy                           0.73      8075
#    macro avg       0.76      0.72      0.70      8075
# weighted avg       0.78      0.73      0.72      8075
# training on fold 1:
# Epoch 1/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.8096 - accuracy: 0.6201 - val_loss: 1.4237 - val_accuracy: 0.3108
#
# Epoch 00001: val_loss improved from inf to 1.42366, saving model to ./models/CNN_base4\best_model_1.h5
# Epoch 2/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.6625 - accuracy: 0.6965 - val_loss: 1.3879 - val_accuracy: 0.3314
#
# Epoch 00002: val_loss improved from 1.42366 to 1.38790, saving model to ./models/CNN_base4\best_model_1.h5
# Epoch 3/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.5630 - accuracy: 0.7504 - val_loss: 1.5515 - val_accuracy: 0.2598
#
# Epoch 00003: val_loss did not improve from 1.38790
# Epoch 4/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4842 - accuracy: 0.7851 - val_loss: 1.4993 - val_accuracy: 0.3854
#
# Epoch 00004: val_loss did not improve from 1.38790
# Epoch 5/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4178 - accuracy: 0.8194 - val_loss: 1.6106 - val_accuracy: 0.3418
#
# Epoch 00005: val_loss did not improve from 1.38790
# Epoch 6/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.3619 - accuracy: 0.8469 - val_loss: 1.1905 - val_accuracy: 0.5254
#
# Epoch 00006: val_loss improved from 1.38790 to 1.19051, saving model to ./models/CNN_base4\best_model_1.h5
# Epoch 7/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.3181 - accuracy: 0.8662 - val_loss: 1.2753 - val_accuracy: 0.5159
#
# Epoch 00007: val_loss did not improve from 1.19051
# Epoch 8/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.2816 - accuracy: 0.8820 - val_loss: 1.8378 - val_accuracy: 0.3885
#
# Epoch 00008: val_loss did not improve from 1.19051
# Epoch 9/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.2544 - accuracy: 0.8967 - val_loss: 1.2644 - val_accuracy: 0.5920
#
# Epoch 00009: val_loss did not improve from 1.19051
# Epoch 10/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2303 - accuracy: 0.9065 - val_loss: 1.1021 - val_accuracy: 0.6557
#
# Epoch 00010: val_loss improved from 1.19051 to 1.10211, saving model to ./models/CNN_base4\best_model_1.h5
# Epoch 11/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.2063 - accuracy: 0.9171 - val_loss: 1.6901 - val_accuracy: 0.5754
#
# Epoch 00011: val_loss did not improve from 1.10211
# Epoch 12/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1975 - accuracy: 0.9210 - val_loss: 1.5883 - val_accuracy: 0.6201
#
# Epoch 00012: val_loss did not improve from 1.10211
# Epoch 13/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1828 - accuracy: 0.9282 - val_loss: 1.9167 - val_accuracy: 0.5548
#
# Epoch 00013: val_loss did not improve from 1.10211
# Epoch 14/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1679 - accuracy: 0.9349 - val_loss: 1.6103 - val_accuracy: 0.6153
#
# Epoch 00014: val_loss did not improve from 1.10211
# Epoch 15/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1616 - accuracy: 0.9354 - val_loss: 1.7776 - val_accuracy: 0.6071
#
# Epoch 00015: val_loss did not improve from 1.10211
# Epoch 16/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1444 - accuracy: 0.9441 - val_loss: 2.0265 - val_accuracy: 0.5807
#
# Epoch 00016: val_loss did not improve from 1.10211
# Epoch 17/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1479 - accuracy: 0.9442 - val_loss: 1.7660 - val_accuracy: 0.6410
#
# Epoch 00017: val_loss did not improve from 1.10211
# Epoch 18/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1370 - accuracy: 0.9479 - val_loss: 2.0968 - val_accuracy: 0.6110
#
# Epoch 00018: val_loss did not improve from 1.10211
# Epoch 19/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1368 - accuracy: 0.9483 - val_loss: 2.4489 - val_accuracy: 0.5712
#
# Epoch 00019: val_loss did not improve from 1.10211
# Epoch 20/100
# 1615/1615 [==============================] - 22s 13ms/step - loss: 0.1301 - accuracy: 0.9503 - val_loss: 3.1213 - val_accuracy: 0.5184
#
# Epoch 00020: val_loss did not improve from 1.10211
# Epoch 21/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1207 - accuracy: 0.9543 - val_loss: 2.2001 - val_accuracy: 0.6283
#
# Epoch 00021: val_loss did not improve from 1.10211
# Epoch 22/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1082 - accuracy: 0.9605 - val_loss: 3.5568 - val_accuracy: 0.4912
#
# Epoch 00022: val_loss did not improve from 1.10211
# Epoch 23/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1191 - accuracy: 0.9556 - val_loss: 2.8587 - val_accuracy: 0.5509
#
# Epoch 00023: val_loss did not improve from 1.10211
# Epoch 24/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1117 - accuracy: 0.9591 - val_loss: 3.2251 - val_accuracy: 0.5163
#
# Epoch 00024: val_loss did not improve from 1.10211
# Epoch 25/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1001 - accuracy: 0.9631 - val_loss: 2.5392 - val_accuracy: 0.6136
#
# Epoch 00025: val_loss did not improve from 1.10211
# Epoch 26/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1067 - accuracy: 0.9592 - val_loss: 3.1323 - val_accuracy: 0.5624
#
# Epoch 00026: val_loss did not improve from 1.10211
# Epoch 27/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.0981 - accuracy: 0.9635 - val_loss: 3.8783 - val_accuracy: 0.4769
#
# Epoch 00027: val_loss did not improve from 1.10211
# Epoch 28/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1053 - accuracy: 0.9613 - val_loss: 3.4286 - val_accuracy: 0.5231
#
# Epoch 00028: val_loss did not improve from 1.10211
# Epoch 29/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0998 - accuracy: 0.9647 - val_loss: 2.7573 - val_accuracy: 0.6224
#
# Epoch 00029: val_loss did not improve from 1.10211
# Epoch 30/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0908 - accuracy: 0.9671 - val_loss: 4.0485 - val_accuracy: 0.5073
#
# Epoch 00030: val_loss did not improve from 1.10211
# Test set performance:
# Weighted AUC(OvR): 0.9418611268240592
# Weighted AUC(OvO): 0.9354736296901747
# Weighted F1 score = 0.8049126650410882
# Weighted Precision = 0.8088650673520491, Weighted Recall = 0.8058204334365325, Accuracy = 0.8058204334365325
# Confusion matrix:
#
# [[1724  181  335]
#  [ 187 3020   68]
#  [ 597  200 1763]]
# Result of classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73      2240
#            1       0.89      0.92      0.90      3275
#            2       0.81      0.69      0.75      2560
#
#     accuracy                           0.81      8075
#    macro avg       0.80      0.79      0.79      8075
# weighted avg       0.81      0.81      0.80      8075
# training on fold 2:
# Epoch 1/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.8009 - accuracy: 0.6285 - val_loss: 1.3541 - val_accuracy: 0.3724
#
# Epoch 00001: val_loss improved from inf to 1.35411, saving model to ./models/CNN_base4\best_model_2.h5
# Epoch 2/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.6159 - accuracy: 0.7239 - val_loss: 1.2156 - val_accuracy: 0.4229
#
# Epoch 00002: val_loss improved from 1.35411 to 1.21563, saving model to ./models/CNN_base4\best_model_2.h5
# Epoch 3/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.5035 - accuracy: 0.7806 - val_loss: 1.8172 - val_accuracy: 0.2337
#
# Epoch 00003: val_loss did not improve from 1.21563
# Epoch 4/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4154 - accuracy: 0.8231 - val_loss: 1.3285 - val_accuracy: 0.3743
#
# Epoch 00004: val_loss did not improve from 1.21563
# Epoch 5/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3525 - accuracy: 0.8494 - val_loss: 1.1322 - val_accuracy: 0.5207
#
# Epoch 00005: val_loss improved from 1.21563 to 1.13216, saving model to ./models/CNN_base4\best_model_2.h5
# Epoch 6/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3054 - accuracy: 0.8712 - val_loss: 1.1913 - val_accuracy: 0.5601
#
# Epoch 00006: val_loss did not improve from 1.13216
# Epoch 7/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2676 - accuracy: 0.8883 - val_loss: 1.6055 - val_accuracy: 0.4762
#
# Epoch 00007: val_loss did not improve from 1.13216
# Epoch 8/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2420 - accuracy: 0.8983 - val_loss: 1.7994 - val_accuracy: 0.4478
#
# Epoch 00008: val_loss did not improve from 1.13216
# Epoch 9/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2188 - accuracy: 0.9098 - val_loss: 1.4390 - val_accuracy: 0.5799
#
# Epoch 00009: val_loss did not improve from 1.13216
# Epoch 10/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1982 - accuracy: 0.9192 - val_loss: 1.5473 - val_accuracy: 0.5885
#
# Epoch 00010: val_loss did not improve from 1.13216
# Epoch 11/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1818 - accuracy: 0.9273 - val_loss: 1.9537 - val_accuracy: 0.5543
#
# Epoch 00011: val_loss did not improve from 1.13216
# Epoch 12/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1624 - accuracy: 0.9354 - val_loss: 2.3308 - val_accuracy: 0.5065
#
# Epoch 00012: val_loss did not improve from 1.13216
# Epoch 13/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1586 - accuracy: 0.9356 - val_loss: 2.8776 - val_accuracy: 0.4500
#
# Epoch 00013: val_loss did not improve from 1.13216
# Epoch 14/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1479 - accuracy: 0.9406 - val_loss: 1.9094 - val_accuracy: 0.6019
#
# Epoch 00014: val_loss did not improve from 1.13216
# Epoch 15/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1338 - accuracy: 0.9471 - val_loss: 1.8411 - val_accuracy: 0.6334
#
# Epoch 00015: val_loss did not improve from 1.13216
# Epoch 16/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1337 - accuracy: 0.9472 - val_loss: 2.3014 - val_accuracy: 0.5724
#
# Epoch 00016: val_loss did not improve from 1.13216
# Epoch 17/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1187 - accuracy: 0.9525 - val_loss: 2.3471 - val_accuracy: 0.5918
#
# Epoch 00017: val_loss did not improve from 1.13216
# Epoch 18/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1205 - accuracy: 0.9529 - val_loss: 2.5536 - val_accuracy: 0.5988
#
# Epoch 00018: val_loss did not improve from 1.13216
# Epoch 19/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1131 - accuracy: 0.9558 - val_loss: 2.6164 - val_accuracy: 0.5396
#
# Epoch 00019: val_loss did not improve from 1.13216
# Epoch 20/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1123 - accuracy: 0.9558 - val_loss: 2.5677 - val_accuracy: 0.5636
#
# Epoch 00020: val_loss did not improve from 1.13216
# Epoch 21/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1057 - accuracy: 0.9576 - val_loss: 2.1954 - val_accuracy: 0.5789
#
# Epoch 00021: val_loss did not improve from 1.13216
# Epoch 22/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1042 - accuracy: 0.9590 - val_loss: 2.1934 - val_accuracy: 0.6632
#
# Epoch 00022: val_loss did not improve from 1.13216
# Epoch 23/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1055 - accuracy: 0.9591 - val_loss: 2.5452 - val_accuracy: 0.5827
#
# Epoch 00023: val_loss did not improve from 1.13216
# Epoch 24/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0978 - accuracy: 0.9630 - val_loss: 2.6848 - val_accuracy: 0.5302
#
# Epoch 00024: val_loss did not improve from 1.13216
# Epoch 25/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0899 - accuracy: 0.9652 - val_loss: 2.6421 - val_accuracy: 0.6234
#
# Epoch 00025: val_loss did not improve from 1.13216
# Test set performance:
# Weighted AUC(OvR): 0.9380987054874225
# Weighted AUC(OvO): 0.9308531354568055
# Weighted F1 score = 0.7805110548602773
# Weighted Precision = 0.8048856836385713, Weighted Recall = 0.7836264552885807, Accuracy = 0.7836264552885807
# Confusion matrix:
#
# [[1796  271  173]
#  [ 219 3043   12]
#  [ 850  222 1488]]
# Result of classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.80      0.70      2240
#            1       0.86      0.93      0.89      3274
#            2       0.89      0.58      0.70      2560
#
#     accuracy                           0.78      8074
#    macro avg       0.79      0.77      0.77      8074
# weighted avg       0.80      0.78      0.78      8074
# training on fold 3:
# Epoch 1/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.8007 - accuracy: 0.6247 - val_loss: 1.5915 - val_accuracy: 0.1673
#
# Epoch 00001: val_loss improved from inf to 1.59152, saving model to ./models/CNN_base4\best_model_3.h5
# Epoch 2/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.6188 - accuracy: 0.7200 - val_loss: 1.2265 - val_accuracy: 0.4653
#
# Epoch 00002: val_loss improved from 1.59152 to 1.22648, saving model to ./models/CNN_base4\best_model_3.h5
# Epoch 3/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.5000 - accuracy: 0.7831 - val_loss: 1.5353 - val_accuracy: 0.3457
#
# Epoch 00003: val_loss did not improve from 1.22648
# Epoch 4/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4069 - accuracy: 0.8282 - val_loss: 1.4476 - val_accuracy: 0.4245
#
# Epoch 00004: val_loss did not improve from 1.22648
# Epoch 5/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3400 - accuracy: 0.8583 - val_loss: 1.4179 - val_accuracy: 0.4534
#
# Epoch 00005: val_loss did not improve from 1.22648
# Epoch 6/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2938 - accuracy: 0.8772 - val_loss: 1.0218 - val_accuracy: 0.6339
#
# Epoch 00006: val_loss improved from 1.22648 to 1.02180, saving model to ./models/CNN_base4\best_model_3.h5
# Epoch 7/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2520 - accuracy: 0.8975 - val_loss: 1.6924 - val_accuracy: 0.5224
#
# Epoch 00007: val_loss did not improve from 1.02180
# Epoch 8/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2172 - accuracy: 0.9102 - val_loss: 1.3923 - val_accuracy: 0.5794
#
# Epoch 00008: val_loss did not improve from 1.02180
# Epoch 9/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2055 - accuracy: 0.9184 - val_loss: 1.6146 - val_accuracy: 0.5762
#
# Epoch 00009: val_loss did not improve from 1.02180
# Epoch 10/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1839 - accuracy: 0.9271 - val_loss: 1.4640 - val_accuracy: 0.6105
#
# Epoch 00010: val_loss did not improve from 1.02180
# Epoch 11/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1636 - accuracy: 0.9366 - val_loss: 1.9426 - val_accuracy: 0.5779
#
# Epoch 00011: val_loss did not improve from 1.02180
# Epoch 12/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1525 - accuracy: 0.9403 - val_loss: 1.9234 - val_accuracy: 0.5492
#
# Epoch 00012: val_loss did not improve from 1.02180
# Epoch 13/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1440 - accuracy: 0.9447 - val_loss: 2.0439 - val_accuracy: 0.6127
#
# Epoch 00013: val_loss did not improve from 1.02180
# Epoch 14/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1328 - accuracy: 0.9497 - val_loss: 2.6908 - val_accuracy: 0.5348
#
# Epoch 00014: val_loss did not improve from 1.02180
# Epoch 15/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1255 - accuracy: 0.9525 - val_loss: 1.8884 - val_accuracy: 0.6443
#
# Epoch 00015: val_loss did not improve from 1.02180
# Epoch 16/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1208 - accuracy: 0.9548 - val_loss: 2.1520 - val_accuracy: 0.6156
#
# Epoch 00016: val_loss did not improve from 1.02180
# Epoch 17/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1081 - accuracy: 0.9589 - val_loss: 3.9663 - val_accuracy: 0.4505
#
# Epoch 00017: val_loss did not improve from 1.02180
# Epoch 18/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1185 - accuracy: 0.9562 - val_loss: 2.7228 - val_accuracy: 0.5811
#
# Epoch 00018: val_loss did not improve from 1.02180
# Epoch 19/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1081 - accuracy: 0.9608 - val_loss: 3.3261 - val_accuracy: 0.5537
#
# Epoch 00019: val_loss did not improve from 1.02180
# Epoch 20/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0967 - accuracy: 0.9644 - val_loss: 5.5187 - val_accuracy: 0.4023
#
# Epoch 00020: val_loss did not improve from 1.02180
# Epoch 21/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1017 - accuracy: 0.9642 - val_loss: 2.1806 - val_accuracy: 0.6526
#
# Epoch 00021: val_loss did not improve from 1.02180
# Epoch 22/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.0960 - accuracy: 0.9649 - val_loss: 3.1088 - val_accuracy: 0.5824
#
# Epoch 00022: val_loss did not improve from 1.02180
# Epoch 23/100
# 1615/1615 [==============================] - 22s 13ms/step - loss: 0.0926 - accuracy: 0.9653 - val_loss: 2.7996 - val_accuracy: 0.6184
#
# Epoch 00023: val_loss did not improve from 1.02180
# Epoch 24/100
# 1615/1615 [==============================] - 23s 14ms/step - loss: 0.0906 - accuracy: 0.9667 - val_loss: 4.3416 - val_accuracy: 0.5017
#
# Epoch 00024: val_loss did not improve from 1.02180
# Epoch 25/100
# 1615/1615 [==============================] - 23s 14ms/step - loss: 0.0779 - accuracy: 0.9724 - val_loss: 4.5037 - val_accuracy: 0.4862
#
# Epoch 00025: val_loss did not improve from 1.02180
# Epoch 26/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.0910 - accuracy: 0.9673 - val_loss: 3.0194 - val_accuracy: 0.5969
#
# Epoch 00026: val_loss did not improve from 1.02180
# Test set performance:
# Weighted AUC(OvR): 0.9437902687292182
# Weighted AUC(OvO): 0.9369986401477453
# Weighted F1 score = 0.8056897305718589
# Weighted Precision = 0.8132093311066805, Weighted Recall = 0.8071587812732227, Accuracy = 0.8071587812732227
# Confusion matrix:
#
# [[1739  194  307]
#  [ 179 3075   20]
#  [ 670  187 1703]]
# Result of classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72      2240
#            1       0.89      0.94      0.91      3274
#            2       0.84      0.67      0.74      2560
#
#     accuracy                           0.81      8074
#    macro avg       0.80      0.79      0.79      8074
# weighted avg       0.81      0.81      0.81      8074
# training on fold 4:
# Epoch 1/100
# 1615/1615 [==============================] - 22s 13ms/step - loss: 0.8198 - accuracy: 0.6156 - val_loss: 2.2506 - val_accuracy: 0.1576
#
# Epoch 00001: val_loss improved from inf to 2.25064, saving model to ./models/CNN_base4\best_model_4.h5
# Epoch 2/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.6587 - accuracy: 0.7052 - val_loss: 1.9467 - val_accuracy: 0.1822
#
# Epoch 00002: val_loss improved from 2.25064 to 1.94672, saving model to ./models/CNN_base4\best_model_4.h5
# Epoch 3/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.5603 - accuracy: 0.7497 - val_loss: 1.0178 - val_accuracy: 0.4841
#
# Epoch 00003: val_loss improved from 1.94672 to 1.01782, saving model to ./models/CNN_base4\best_model_4.h5
# Epoch 4/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4841 - accuracy: 0.7873 - val_loss: 1.6211 - val_accuracy: 0.3067
#
# Epoch 00004: val_loss did not improve from 1.01782
# Epoch 5/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.4150 - accuracy: 0.8199 - val_loss: 1.1549 - val_accuracy: 0.4918
#
# Epoch 00005: val_loss did not improve from 1.01782
# Epoch 6/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3593 - accuracy: 0.8460 - val_loss: 1.4999 - val_accuracy: 0.3817
#
# Epoch 00006: val_loss did not improve from 1.01782
# Epoch 7/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.3190 - accuracy: 0.8631 - val_loss: 1.2390 - val_accuracy: 0.5320
#
# Epoch 00007: val_loss did not improve from 1.01782
# Epoch 8/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.2865 - accuracy: 0.8798 - val_loss: 0.7889 - val_accuracy: 0.6618
#
# Epoch 00008: val_loss improved from 1.01782 to 0.78892, saving model to ./models/CNN_base4\best_model_4.h5
# Epoch 9/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2531 - accuracy: 0.8927 - val_loss: 1.2346 - val_accuracy: 0.6029
#
# Epoch 00009: val_loss did not improve from 0.78892
# Epoch 10/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2351 - accuracy: 0.9024 - val_loss: 1.2313 - val_accuracy: 0.5755
#
# Epoch 00010: val_loss did not improve from 0.78892
# Epoch 11/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.2171 - accuracy: 0.9070 - val_loss: 1.4966 - val_accuracy: 0.5063
#
# Epoch 00011: val_loss did not improve from 0.78892
# Epoch 12/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1981 - accuracy: 0.9162 - val_loss: 1.7356 - val_accuracy: 0.5040
#
# Epoch 00012: val_loss did not improve from 0.78892
# Epoch 13/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1816 - accuracy: 0.9252 - val_loss: 1.9103 - val_accuracy: 0.5299
#
# Epoch 00013: val_loss did not improve from 0.78892
# Epoch 14/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1651 - accuracy: 0.9299 - val_loss: 1.2880 - val_accuracy: 0.6551
#
# Epoch 00014: val_loss did not improve from 0.78892
# Epoch 15/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1616 - accuracy: 0.9329 - val_loss: 1.8212 - val_accuracy: 0.5957
#
# Epoch 00015: val_loss did not improve from 0.78892
# Epoch 16/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1481 - accuracy: 0.9396 - val_loss: 1.7912 - val_accuracy: 0.6091
#
# Epoch 00016: val_loss did not improve from 0.78892
# Epoch 17/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1411 - accuracy: 0.9417 - val_loss: 2.1751 - val_accuracy: 0.5732
#
# Epoch 00017: val_loss did not improve from 0.78892
# Epoch 18/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1358 - accuracy: 0.9458 - val_loss: 2.2223 - val_accuracy: 0.5618
#
# Epoch 00018: val_loss did not improve from 0.78892
# Epoch 19/100
# 1615/1615 [==============================] - 21s 13ms/step - loss: 0.1335 - accuracy: 0.9464 - val_loss: 2.3077 - val_accuracy: 0.6169
#
# Epoch 00019: val_loss did not improve from 0.78892
# Epoch 20/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1277 - accuracy: 0.9485 - val_loss: 2.0902 - val_accuracy: 0.6475
#
# Epoch 00020: val_loss did not improve from 0.78892
# Epoch 21/100
# 1615/1615 [==============================] - 20s 13ms/step - loss: 0.1190 - accuracy: 0.9521 - val_loss: 2.7302 - val_accuracy: 0.5384
#
# Epoch 00021: val_loss did not improve from 0.78892
# Epoch 22/100
# 1615/1615 [==============================] - 20s 12ms/step - loss: 0.1168 - accuracy: 0.9536 - val_loss: 2.4249 - val_accuracy: 0.5864
#
# Epoch 00022: val_loss did not improve from 0.78892
# Epoch 23/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1069 - accuracy: 0.9584 - val_loss: 2.9438 - val_accuracy: 0.5604
#
# Epoch 00023: val_loss did not improve from 0.78892
# Epoch 24/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1118 - accuracy: 0.9563 - val_loss: 2.2619 - val_accuracy: 0.6254
#
# Epoch 00024: val_loss did not improve from 0.78892
# Epoch 25/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1050 - accuracy: 0.9590 - val_loss: 3.2701 - val_accuracy: 0.5077
#
# Epoch 00025: val_loss did not improve from 0.78892
# Epoch 26/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1093 - accuracy: 0.9568 - val_loss: 2.3891 - val_accuracy: 0.6416
#
# Epoch 00026: val_loss did not improve from 0.78892
# Epoch 27/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1002 - accuracy: 0.9600 - val_loss: 2.5437 - val_accuracy: 0.6009
#
# Epoch 00027: val_loss did not improve from 0.78892
# Epoch 28/100
# 1615/1615 [==============================] - 19s 12ms/step - loss: 0.1015 - accuracy: 0.9601 - val_loss: 2.6572 - val_accuracy: 0.5811
#
# Epoch 00028: val_loss did not improve from 0.78892
# Test set performance:
# Weighted AUC(OvR): 0.9369442917592564
# Weighted AUC(OvO): 0.9300010209607925
# Weighted F1 score = 0.8039474765165756
# Weighted Precision = 0.8063022540087922, Weighted Recall = 0.804062422591033, Accuracy = 0.804062422591033
# Confusion matrix:
#
# [[1647  205  388]
#  [ 216 3007   51]
#  [ 573  149 1838]]
# Result of classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.74      0.70      2240
#            1       0.89      0.92      0.91      3274
#            2       0.81      0.72      0.76      2560
#
#     accuracy                           0.80      8074
#    macro avg       0.79      0.79      0.79      8074
# weighted avg       0.81      0.80      0.80      8074

# %%
print('Result of 5-fold Cross-validation on Test set data:')
print(f'weighted f1 score :{weighted_f1_list}\n')
print(f'Average of weighted auc OvR in 5 folds: {np.mean(auc_ovr_list)}')
print(f'Variance of weighted auc OvR in 5 folds: {np.var(auc_ovr_list)}')
print(f'Average of weighted auc OvO in 5 folds: {np.mean(auc_ovo_list)}')
print(f'Variance of weighted auc OvO in 5 folds: {np.var(auc_ovo_list)}')
print(f'Average of weighted F1 Score in 5 folds: {np.mean(weighted_f1_list)}')
print(f'Variance of Weighted F1 Score in 5 folds: {np.var(weighted_f1_list)}')

#print(f'Average Precision: { np.mean(precision_list)}')
#print(f'Variance of Precision: {np.var(precision_list)}')

#print(f'Average Recall: {np.mean(recall_list)}')
#print(f'Variance of Recall: {np.var(recall_list)}')
# Out:
# Result of 5-fold Cross-validation on Test set data:
# weighted f1 score :[0.721826039399566, 0.8049126650410882, 0.7805110548602773, 0.8056897305718589, 0.8039474765165756]
#
# Average of weighted auc OvR in 5 folds: 0.9360554294254767
# Variance of weighted auc OvR in 5 folds: 7.39695879076491e-05
# Average of weighted auc OvO in 5 folds: 0.9287940861312262
# Variance of weighted auc OvO in 5 folds: 8.941057028036179e-05
# Average of weighted F1 Score in 5 folds: 0.7833773932778731
# Variance of Weighted F1 Score in 5 folds: 0.0010363043420120082
